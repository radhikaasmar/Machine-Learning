# %% [markdown]
# # Pandas Read CSV

# %%
import pandas as pd

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# ...

# %%
pd.read_csv('Downloads//student_results.csv')
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# ...

# %%
pd.read_csv('Downloads/Top-10-IT-Companies-in-India.csv')
# Out:
#   Top 10 IT Companies in India
# 0                          TCS
# 1                      Infosys
# 2                Tech Mahindra
# 3                        Wipro
# 4             HCL Technologies
# 5                 L&T Infotech
# 6                     Mindtree
# 7                      Mphasis
# 8    Oracle Financial Services
# 9                  Rotla India
