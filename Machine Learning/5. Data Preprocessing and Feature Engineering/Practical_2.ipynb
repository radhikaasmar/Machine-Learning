# %% [markdown]
# # Missing Valye imputation by Mean, Median

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train.csv')

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
missing_value_per = df.isnull().sum()/df.shape[0]*100
missing_value_per
# Out:
# Id                0.000000
# MSSubClass        0.000000
# MSZoning          0.000000
# LotFrontage      17.739726
# LotArea           0.000000
#                    ...
# MoSold            0.000000
# YrSold            0.000000
# SaleType          0.000000
# SaleCondition     0.000000
# SalePrice         0.000000
# Length: 81, dtype: float64

# %%
missing_value_clm_gre_20 = missing_value_per[missing_value_per >20].keys()
missing_value_clm_gre_20
# Out:
# Index(['Alley', 'MasVnrType', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature'], dtype='object')

# %%
df2_drop_clm = df.drop(columns = missing_value_clm_gre_20)
df2_drop_clm.shape
# Out:
# (1460, 75)

# %%
df.shape
# Out:
# (1460, 81)

# %%
df3_num = df2_drop_clm.select_dtypes(include = ['int64', 'float64'])
df3_num.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  OpenPorchSF  \
# 0          2003       196.0         706  ...           0           61
# 1          1976         0.0         978  ...         298            0
# 2          2002       162.0         486  ...           0           42
# 3          1970         0.0         216  ...           0           35
# 4          2000       350.0         655  ...         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# 0              0          0            0         0        0       2    2008
# 1              0          0            0         0        0       5    2007
# 2              0          0            0         0        0       9    2008
# 3            272          0            0         0        0       2    2006
# 4              0          0            0         0        0      12    2008
#
#    SalePrice
# 0     208500
# 1     181500
# 2     223500
# 3     140000
# 4     250000
#
# [5 rows x 38 columns]

# %%
plt.figure(figsize=(16,9))
sns.heatmap(df3_num.isnull())
# Out:
# <Axes: >

# %%
df3_num[df3_num.isnull().any(axis=1)]
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 7        8          60          NaN    10382            7            6
# 12      13          20          NaN    12968            5            6
# 14      15          20          NaN    10920            6            5
# 16      17          20          NaN    11241            6            7
# 24      25          20          NaN     8246            5            8
# ...    ...         ...          ...      ...          ...          ...
# 1443  1444          30          NaN     8854            6            6
# 1446  1447          20          NaN    26142            5            7
# 1449  1450         180         21.0     1533            5            7
# 1450  1451          90         60.0     9000            5            5
# 1453  1454          20         90.0    17217            5            5
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  \
# 7          1973          1973       240.0         859  ...         235
# 12         1962          1962         0.0         737  ...         140
# 14         1960          1960       212.0         733  ...           0
# 16         1970          1970       180.0         578  ...           0
# 24         1968          2001         0.0         188  ...         406
# ...         ...           ...         ...         ...  ...         ...
# 1443       1916          1950         0.0           0  ...           0
# 1446       1962          1962       189.0         593  ...         261
# 1449       1970          1970         0.0         553  ...           0
# 1450       1974          1974         0.0           0  ...          32
# 1453       2006          2006         0.0           0  ...          36
#
#       OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# 7             204            228          0            0         0      350
# 12              0              0          0          176         0        0
# 14            213            176          0            0         0        0
# 16              0              0          0            0         0      700
# 24             90              0          0            0         0        0
# ...           ...            ...        ...          ...       ...      ...
# 1443           98              0          0           40         0        0
# 1446           39              0          0            0         0        0
# 1449            0              0          0            0         0        0
# 1450           45              0          0            0         0        0
# 1453           56              0          0            0         0        0
#
#       MoSold  YrSold  SalePrice
# 7         11    2009     200000
# 12         9    2008     144000
# 14         5    2008     157000
# 16         3    2010     149000
# 24         5    2010     154000
# ...      ...     ...        ...
# 1443       5    2009     121000
# 1446       4    2010     157900
# 1449       8    2006      92000
# 1450       9    2009     136000
# 1453       7    2006      84500
#
# [339 rows x 38 columns]

# %%
df3_num.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# LotFrontage      259
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         8
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       81
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# SalePrice          0
# dtype: int64

# %%
missing_num_var = [var for var in df3_num.columns if df3_num[var].isnull().sum()>0]
missing_num_var
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %%
plt.figure(figsize=(10,10))
sns.set()
for i, var in enumerate(missing_num_var):
    plt.subplot(2,2,i+1)
    sns.distplot(df3_num[var], bins=20, kde_kws={'linewidth':5, 'color':'#DC143C'})
# Out:
# /var/folders/4_/7fhgy55n52j_k9m76p98r3vw0000gn/T/ipykernel_1208/3302574415.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df3_num[var], bins=20, kde_kws={'linewidth':5, 'color':'#DC143C'})
# /var/folders/4_/7fhgy55n52j_k9m76p98r3vw0000gn/T/ipykernel_1208/3302574415.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df3_num[var], bins=20, kde_kws={'linewidth':5, 'color':'#DC143C'})
# /var/folders/4_/7fhgy55n52j_k9m76p98r3vw0000gn/T/ipykernel_1208/3302574415.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df3_num[var], bins=20, kde_kws={'linewidth':5, 'color':'#DC143C'})

# %%
df4_num_mean = df3_num.fillna(df3_num.mean())
df4_num_mean.isnull().sum().sum()
# Out:
# 0

# %%
plt.figure(figsize=(10,10))
sns.set()
for i, var in enumerate(missing_num_var):
    plt.subplot(2,2,i+1)
    sns.distplot(df3_num[var], bins=20, kde_kws={'linewidth':8, 'color':'red'}, label="Original",)
    sns.distplot(df4_num_mean[var], bins=20, kde_kws={'linewidth':5, 'color':'green'},label="Mean",)
    plt.legend()
# Out:
# /var/folders/4_/7fhgy55n52j_k9m76p98r3vw0000gn/T/ipykernel_1208/2980977048.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df3_num[var], bins=20, kde_kws={'linewidth':8, 'color':'red'}, label="Original",)
# /var/folders/4_/7fhgy55n52j_k9m76p98r3vw0000gn/T/ipykernel_1208/2980977048.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df4_num_mean[var], bins=20, kde_kws={'linewidth':5, 'color':'green'},label="Mean",)
# /var/folders/4_/7fhgy55n52j_k9m76p98r3vw0000gn/T/ipykernel_1208/2980977048.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df3_num[var], bins=20, kde_kws={'linewidth':8, 'color':'red'}, label="Original",)
# /var/folders/4_/7fhgy55n52j_k9m76p98r3vw0000gn/T/ipykernel_1208/2980977048.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df4_num_mean[var], bins=20, kde_kws={'linewidth':5, 'color':'green'},label="Mean",)
# /var/folders/4_/7fhgy55n52j_k9m76p98r3vw0000gn/T/ipykernel_1208/2980977048.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df3_num[var], bins=20, kde_kws={'linewidth':8, 'color':'red'}, label="Original",)
# /var/folders/4_/7fhgy55n52j_k9m76p98r3vw0000gn/T/ipykernel_1208/2980977048.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df4_num_mean[var], bins=20, kde_kws={'linewidth':5, 'color':'green'},label="Mean",)

# %%
df5_num_median = df3_num.fillna(df3_num.median())
df5_num_median.isnull().sum().sum()
# Out:
# 0

# %%
plt.figure(figsize=(10,10))
sns.set()
for i, var in enumerate(missing_num_var):
    plt.subplot(2,2,i+1)
    sns.distplot(df3_num[var], bins=20,hist=False, kde_kws={'linewidth':8, 'color':'red'}, label="Original",)
    sns.distplot(df4_num_mean[var], bins=20,hist=False, kde_kws={'linewidth':5, 'color':'green'},label="Mean",)
    sns.distplot(df5_num_median[var], bins=20,hist=False, kde_kws={'linewidth':3, 'color':'k'},label="Median",)
    plt.legend()
# Out:
# /var/folders/4_/7fhgy55n52j_k9m76p98r3vw0000gn/T/ipykernel_1208/888168502.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df3_num[var], bins=20,hist=False, kde_kws={'linewidth':8, 'color':'red'}, label="Original",)
# /var/folders/4_/7fhgy55n52j_k9m76p98r3vw0000gn/T/ipykernel_1208/888168502.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df4_num_mean[var], bins=20,hist=False, kde_kws={'linewidth':5, 'color':'green'},label="Mean",)
# /var/folders/4_/7fhgy55n52j_k9m76p98r3vw0000gn/T/ipykernel_1208/888168502.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df5_num_median[var], bins=20,hist=False, kde_kws={'linewidth':3, 'color':'k'},label="Median",)
# /var/folders/4_/7fhgy55n52j_k9m76p98r3vw0000gn/T/ipykernel_1208/888168502.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df3_num[var], bins=20,hist=False, kde_kws={'linewidth':8, 'color':'red'}, label="Original",)
# /var/folders/4_/7fhgy55n52j_k9m76p98r3vw0000gn/T/ipykernel_1208/888168502.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df4_num_mean[var], bins=20,hist=False, kde_kws={'linewidth':5, 'color':'green'},label="Mean",)
# /var/folders/4_/7fhgy55n52j_k9m76p98r3vw0000gn/T/ipykernel_1208/888168502.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df5_num_median[var], bins=20,hist=False, kde_kws={'linewidth':3, 'color':'k'},label="Median",)
# /var/folders/4_/7fhgy55n52j_k9m76p98r3vw0000gn/T/ipykernel_1208/888168502.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df3_num[var], bins=20,hist=False, kde_kws={'linewidth':8, 'color':'red'}, label="Original",)
# /var/folders/4_/7fhgy55n52j_k9m76p98r3vw0000gn/T/ipykernel_1208/888168502.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df4_num_mean[var], bins=20,hist=False, kde_kws={'linewidth':5, 'color':'green'},label="Mean",)
# /var/folders/4_/7fhgy55n52j_k9m76p98r3vw0000gn/T/ipykernel_1208/888168502.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df5_num_median[var], bins=20,hist=False, kde_kws={'linewidth':3, 'color':'k'},label="Median",)

# %%
for i, var in enumerate(missing_num_var):
    plt.figure(figsize=(10,10))
    plt.subplot(3,1,1)
    sns.boxplot(df[var])
    plt.subplot(3,1,2)
    sns.boxplot(df4_num_mean[var])
    plt.subplot(3,1,3)
    sns.boxplot(df5_num_median[var])

# %%
df_concat = pd.concat([df3_num[missing_num_var],df4_num_mean[missing_num_var],df5_num_median[missing_num_var]], axis=1)

# %%
df_concat[df_concat.isnull().any(axis=1)]
# Out:
#       LotFrontage  MasVnrArea  GarageYrBlt  LotFrontage  MasVnrArea  \
# 7             NaN       240.0       1973.0    70.049958       240.0
# 12            NaN         0.0       1962.0    70.049958         0.0
# 14            NaN       212.0       1960.0    70.049958       212.0
# 16            NaN       180.0       1970.0    70.049958       180.0
# 24            NaN         0.0       1968.0    70.049958         0.0
# ...           ...         ...          ...          ...         ...
# 1443          NaN         0.0       1916.0    70.049958         0.0
# 1446          NaN       189.0       1962.0    70.049958       189.0
# 1449         21.0         0.0          NaN    21.000000         0.0
# 1450         60.0         0.0          NaN    60.000000         0.0
# 1453         90.0         0.0          NaN    90.000000         0.0
#
#       GarageYrBlt  LotFrontage  MasVnrArea  GarageYrBlt
# 7     1973.000000         69.0       240.0       1973.0
# 12    1962.000000         69.0         0.0       1962.0
# 14    1960.000000         69.0       212.0       1960.0
# 16    1970.000000         69.0       180.0       1970.0
# 24    1968.000000         69.0         0.0       1968.0
# ...           ...          ...         ...          ...
# 1443  1916.000000         69.0         0.0       1916.0
# 1446  1962.000000         69.0       189.0       1962.0
# 1449  1978.506164         21.0         0.0       1980.0
# 1450  1978.506164         60.0         0.0       1980.0
# 1453  1978.506164         90.0         0.0       1980.0
#
# [339 rows x 9 columns]
