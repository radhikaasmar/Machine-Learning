# %% [markdown]
# # Seaborn Barplot

# %%
import seaborn as sns
import numpy as np

# %%
tips_df = sns.load_dataset('tips')
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot()
# Out:
# <Axes: >

# %%
sns.barplot(x=tips_df.total_bill)
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.barplot(x=tips_df.day ,y=tips_df.total_bill)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x=tips_df.day ,y=tips_df.total_bill, hue=tips_df.sex)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day' ,y='total_bill', hue='sex', data=tips_df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
order = ['Sun', 'Thur', 'Fri', 'Sat']
sns.barplot(x='day' ,y='total_bill', hue='sex', data=tips_df, order=order)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
hue_order = ['Female', 'Male']
sns.barplot(x='day' ,y='total_bill', hue='sex', data=tips_df, hue_order=hue_order)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day' ,y='total_bill', hue='sex', data=tips_df, 
           estimator=np.mean)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day' ,y='total_bill', hue='sex', data=tips_df, 
           estimator=np.max)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day' ,y='total_bill', hue='sex', data=tips_df, 
           ci=12)
# Out:
# /var/folders/4_/7fhgy55n52j_k9m76p98r3vw0000gn/T/ipykernel_11414/2739192189.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 12)` for the same effect.
#
#   sns.barplot(x='day' ,y='total_bill', hue='sex', data=tips_df,
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day' ,y='total_bill', hue='sex', data=tips_df, 
           estimator=np.max, n_boot=2)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day' ,y='total_bill', hue='sex', data=tips_df, 
           orient='h')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='total_bill',y='day' , hue='sex', data=tips_df)
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.barplot(x='total_bill', y='size', hue='sex', data=tips_df, orient='h')
# Out:
# <Axes: xlabel='total_bill', ylabel='size'>

# %%
sns.barplot(x='day' ,y='total_bill', hue='sex', data=tips_df, 
           color='r')
# Out:
# /var/folders/4_/7fhgy55n52j_k9m76p98r3vw0000gn/T/ipykernel_11414/2440992649.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:r'` for the same effect.
#
#   sns.barplot(x='day' ,y='total_bill', hue='sex', data=tips_df,
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day' ,y='total_bill', hue='sex', data=tips_df, 
           palette='Blues')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day' ,y='total_bill', hue='sex', data=tips_df, 
           saturation=0.3)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day' ,y='total_bill', hue='sex', data=tips_df, 
           errcolor='0.5')
# Out:
# /var/folders/4_/7fhgy55n52j_k9m76p98r3vw0000gn/T/ipykernel_11414/2462047637.py:1: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': '0.5'}` instead.
#
#   sns.barplot(x='day' ,y='total_bill', hue='sex', data=tips_df,
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day' ,y='total_bill', hue='sex', data=tips_df, 
           errwidth=12)
# Out:
# /var/folders/4_/7fhgy55n52j_k9m76p98r3vw0000gn/T/ipykernel_11414/1398235416.py:1: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 12}` instead.
#
#   sns.barplot(x='day' ,y='total_bill', hue='sex', data=tips_df,
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day' ,y='total_bill', hue='sex', data=tips_df, 
          capsize=0.3)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day' ,y='total_bill', hue='sex', data=tips_df, dodge=False)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
kwargs={'alpha':0.9, 'linestyle': ':', 'linewidth': 5, 'edgecolor':'k'}

sns.barplot(x='day' ,y='total_bill', data=tips_df, **kwargs)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day' ,y='total_bill', data=tips_df, alpha=0.9, linestyle='--', linewidth=3, edgecolor='g')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
ax = sns.barplot(x='day' ,y='total_bill', data=tips_df, alpha=0.9, 
                 linestyle='--', linewidth=3, edgecolor='g')

ax.set(title = 'Barplot of Tips Dataframe',
      xlabel='Days',
      ylabel='Tota; Bill')
# Out:
# [Text(0.5, 1.0, 'Barplot of Tips Dataframe'),
#  Text(0.5, 0, 'Days'),
#  Text(0, 0.5, 'Tota; Bill')]

# %%
plt.figure(figsize=(16,9))

sns.barplot(x='day' ,y='total_bill', data=tips_df, alpha=0.9, 
                 linestyle='--', linewidth=3, edgecolor='g')

plt.title('Barplot of Days and Total Bill')
plt.xlabel('Days')
plt.ylabel('Total Bill')
